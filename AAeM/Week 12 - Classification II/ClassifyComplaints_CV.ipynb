# %% [markdown]
# # Classify complaints per product based on the consumer narrative
#
# ## Multi-classification example with pipeline for algorithm selection using cross-validation
#
# Nuno António - Rev. 1.00 - January, 2020

# %% [markdown]
# ### Dataset description
# Complaints about financial products and services presented to the Consumer Financial Protection Bureau (USA government agency responsible for consumer protection in the financial sector).
#
# The dataset is composed of the following variables:
#
# - **data_received**: date the complaint was received.
# - **product**: type of financial product.
# - **sub_produtc**: type of sub-product.
# - **issue**: summary of the complaint.
# - **sub_issue**: sub-issue of the complaint.
# - **consumer_complaint_narrative**: description of the complaint as made by the consumer.
# - **company_public_response**: response given by the company.
# - **company**: company which complaint was about.
# - **state**: location of the consumer (state).
# - **zip_code**: location of the consumer(zip code).
# - **tags**: classification tags given by agent.
# - **consumer_consent_provided**: consumer consenented information to be used?
# - **submitted_via**: how was the complaint submitted.
# - **date_sent_to_company**: date when complaint was sent to the company.
# - **company_response_to_consumer**: type of response given by the company to the consumer.
# - **timely_response**: was response given in a timely fashion?
# - **consumer_disputed**: consumer disputed the company's response?
# - **complaint_id**: ID of the complaint.
#
#
# More information on the dataset available at https://data.world/chandrasekar/consumer-complaints
#
#
# The objective is to use the what the consumers complained about (in textual format) as features to predict which type of product were they making a complaint about.

# %% [markdown]
# <font color='blue'>Q1: Business-wise, what advantages could be taken from implementing such a model?</font><br>

# %% [markdown]
# ### Initial setup and modules/packages loading

# %%
import os
import csv
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import LinearSVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ### Data understanding

# %%
# Load data 
ds = pd.read_csv('Consumer_Complaints.tsv',sep='\t')
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 18 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   date_received                 5000 non-null   object
#  1   product                       5000 non-null   object
#  2   sub_product                   4173 non-null   object
#  3   issue                         5000 non-null   object
#  4   sub_issue                     3300 non-null   object
#  5   consumer_complaint_narrative  828 non-null    object
#  6   company_public_response       1541 non-null   object
#  7   company                       5000 non-null   object
#  8   state                         4945 non-null   object
#  9   zip_code                      4934 non-null   object
#  10  tags                          667 non-null    object
#  11  consumer_consent_provided     1822 non-null   object
#  12  submitted_via                 5000 non-null   object
#  13  date_sent_to_company          5000 non-null   object
#  14  company_response_to_consumer  5000 non-null   object
#  15  timely_response               5000 non-null   bool
#  16  consumer_disputed             2972 non-null   object
#  17  complaint_id                  5000 non-null   int64
# dtypes: bool(1), int64(1), object(16)
# memory usage: 669.1+ KB

# %%
# Display top 10 rows
ds.head(10)
# Out:
#   date_received                  product  \
# 0    2017-03-21         Credit reporting
# 1    2017-04-19          Debt collection
# 2    2017-04-19              Credit card
# 3    2017-04-14                 Mortgage
# 4    2017-04-19              Credit card
# 5    2017-04-18          Debt collection
# 6    2017-04-18                 Mortgage
# 7    2016-05-18                 Mortgage
# 8    2017-03-17  Bank account or service
# 9    2016-11-18                 Mortgage
#
#                              sub_product  \
# 0                                    NaN
# 1  Other (i.e. phone, health club, etc.)
# 2                                    NaN
# 3                         Other mortgage
# 4                                    NaN
# 5  Other (i.e. phone, health club, etc.)
# 6                         Other mortgage
# 7                         Other mortgage
# 8                       Checking account
# 9            Conventional fixed mortgage
#
#                                       issue  \
# 0    Incorrect information on credit report
# 1           Disclosure verification of debt
# 2                                     Other
# 3  Loan modification,collection,foreclosure
# 4                      Credit determination
# 5           Disclosure verification of debt
# 6  Loan servicing, payments, escrow account
# 7  Loan modification,collection,foreclosure
# 8  Making/receiving payments, sending money
# 9              Settlement process and costs
#
#                                 sub_issue  \
# 0                 Information is not mine
# 1  Not disclosed as an attempt to collect
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5    Not given enough info to verify debt
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
#
#                         consumer_complaint_narrative  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
# 5                                                NaN
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9  Started the refinance of home mortgage process...
#
#                              company_public_response  \
# 0  Company has responded to the consumer and the ...
# 1                                                NaN
# 2  Company has responded to the consumer and the ...
# 3  Company believes it acted appropriately as aut...
# 4  Company has responded to the consumer and the ...
# 5                                                NaN
# 6                                                NaN
# 7  Company has responded to the consumer and the ...
# 8  Company believes it acted appropriately as aut...
# 9                                                NaN
#
#                                   company state zip_code            tags  \
# 0                    EXPERIAN DELAWARE GP    TX    77075  Older American
# 1           Security Credit Services, LLC    IL    60643             NaN
# 2                          CITIBANK, N.A.    IL    62025             NaN
# 3                Shellpoint Partners, LLC    CA    90305             NaN
# 4                            U.S. BANCORP    LA    70571             NaN
# 5                    Rubin & Rothman, LLC    NY    14063             NaN
# 6                     QUICKEN LOANS, INC.    FL    33772  Older American
# 7  WELLS FARGO BANK, NATIONAL ASSOCIATION    NJ    08618             NaN
# 8  UNITED SERVICES AUTOMOBILE ASSOCIATION    WI    54005             NaN
# 9          AMERICAN NEIGHBORHOOD MORTGAGE    NJ    088XX             NaN
#
#   consumer_consent_provided submitted_via date_sent_to_company  \
# 0                       NaN         Phone           2017-03-21
# 1                       NaN           Web           2017-04-20
# 2                       NaN      Referral           2017-04-20
# 3                       NaN      Referral           2017-04-14
# 4                       NaN   Postal mail           2017-04-21
# 5                       NaN      Referral           2017-04-19
# 6                       NaN      Referral           2017-04-19
# 7                       NaN      Referral           2016-05-23
# 8                       NaN      Referral           2017-03-20
# 9          Consent provided           Web           2016-11-21
#
#       company_response_to_consumer  timely_response consumer_disputed  \
# 0  Closed with non-monetary relief             True                No
# 1          Closed with explanation             True                No
# 2          Closed with explanation             True                No
# 3          Closed with explanation             True                No
# 4          Closed with explanation             True                No
# 5                      In progress             True                No
# 6                      In progress             True                No
# 7          Closed with explanation             True                No
# 8          Closed with explanation             True                No
# 9      Closed with monetary relief            False                No
#
#    complaint_id
# 0       2397100
# 1       2441777
# 2       2441830
# 3       2436165
# 4       2441726
# 5       2440364
# 6       2441409
# 7       1931957
# 8       2393048
# 9       2216206

# %%
# Summary statistics for all variables
summary=ds.describe(include='all')
summary=summary.transpose()
summary.head(len(summary))
# Out:
#                                count unique  \
# date_received                   5000    418
# product                         5000     17
# sub_product                     4173     70
# issue                           5000    125
# sub_issue                       3300    156
# consumer_complaint_narrative     828    824
# company_public_response         1541      9
# company                         5000    676
# state                           4945     56
# zip_code                        4934   2437
# tags                             667      3
# consumer_consent_provided       1822      4
# submitted_via                   5000      5
# date_sent_to_company            5000    373
# company_response_to_consumer    5000      8
# timely_response                 5000      2
# consumer_disputed               2972      2
# complaint_id                  5000.0    NaN
#
#                                                                             top  \
# date_received                                                        2017-04-26
# product                                                         Debt collection
# sub_product                                                    Credit reporting
# issue                                      Incorrect information on your report
# sub_issue                                   Information belongs to someone else
# consumer_complaint_narrative  I have encountered many incidents of financial...
# company_public_response       Company has responded to the consumer and the ...
# company                                                    EXPERIAN DELAWARE GP
# state                                                                        CA
# zip_code                                                                  300XX
# tags                                                              Servicemember
# consumer_consent_provided                                  Consent not provided
# submitted_via                                                               Web
# date_sent_to_company                                                 2017-04-25
# company_response_to_consumer                            Closed with explanation
# timely_response                                                            True
# consumer_disputed                                                            No
# complaint_id                                                                NaN
#
#                               freq          mean            std     min  \
# date_received                  466           NaN            NaN     NaN
# product                       1264           NaN            NaN     NaN
# sub_product                    876           NaN            NaN     NaN
# issue                          522           NaN            NaN     NaN
# sub_issue                      177           NaN            NaN     NaN
# consumer_complaint_narrative     2           NaN            NaN     NaN
# company_public_response       1204           NaN            NaN     NaN
# company                        493           NaN            NaN     NaN
# state                          618           NaN            NaN     NaN
# zip_code                        56           NaN            NaN     NaN
# tags                           392           NaN            NaN     NaN
# consumer_consent_provided      945           NaN            NaN     NaN
# submitted_via                 4189           NaN            NaN     NaN
# date_sent_to_company           452           NaN            NaN     NaN
# company_response_to_consumer  3568           NaN            NaN     NaN
# timely_response               4809           NaN            NaN     NaN
# consumer_disputed             2698           NaN            NaN     NaN
# complaint_id                   NaN  2347151.6304  365060.093581  3950.0
#
#                                     25%        50%        75%        max
# date_received                       NaN        NaN        NaN        NaN
# product                             NaN        NaN        NaN        NaN
# sub_product                         NaN        NaN        NaN        NaN
# issue                               NaN        NaN        NaN        NaN
# sub_issue                           NaN        NaN        NaN        NaN
# consumer_complaint_narrative        NaN        NaN        NaN        NaN
# company_public_response             NaN        NaN        NaN        NaN
# company                             NaN        NaN        NaN        NaN
# state                               NaN        NaN        NaN        NaN
# zip_code                            NaN        NaN        NaN        NaN
# tags                                NaN        NaN        NaN        NaN
# consumer_consent_provided           NaN        NaN        NaN        NaN
# submitted_via                       NaN        NaN        NaN        NaN
# date_sent_to_company                NaN        NaN        NaN        NaN
# company_response_to_consumer        NaN        NaN        NaN        NaN
# timely_response                     NaN        NaN        NaN        NaN
# consumer_disputed                   NaN        NaN        NaN        NaN
# complaint_id                  2375706.5  2443758.0  2466461.5  2477451.0

# %%
# Show products (target)
ds['product'].value_counts()
# Out:
# Debt collection                                                                 1264
# Credit reporting, credit repair services, or other personal consumer reports     896
# Mortgage                                                                         741
# Credit reporting                                                                 466
# Student loan                                                                     381
# Credit card                                                                      331
# Bank account or service                                                          300
# Consumer Loan                                                                    179
# Credit card or prepaid card                                                      153
# Checking or savings account                                                       90
# Vehicle loan or lease                                                             60
# Payday loan                                                                       30
# Money transfers                                                                   27
# Money transfer, virtual currency, or money service                                25
# Prepaid card                                                                      23
# Payday loan, title loan, or personal loan                                         23
# Other financial service                                                           11
# Name: product, dtype: int64

# %% [markdown]
# <font color='blue'>Q2: Is the dataset balanced?</font><br>

# %% [markdown]
# ### Data preparation

# %%
# Create a modeling dataset from the original dataset
X = ds.copy(deep=True)

# %%
# Remove rows without narrative
X = X[pd.notnull(X['consumer_complaint_narrative'])]

# %%
# For speed pruposes, let's only use a 5000 sample
#X = X.sample(n=5000, replace=False, random_state=123)

# %%
# Use only "product" and "consumer_complaint_narrative" columns
cols = ['product', 'consumer_complaint_narrative']
X = X[cols]

# %%
# Plot complaints by product
fig = plt.figure(figsize=(8,6))
X.groupby('product').consumer_complaint_narrative.count().plot.bar(ylim=0)
plt.show()

# %%
# Create a column with the product ID (from the category)
X['product_id'] = pd.factorize(X['product'])[0]

# %%
# Create features from the consumer narrative via TF-IDF
tfidf = TfidfVectorizer(sublinear_tf=True, min_df=5, norm='l2', encoding='latin-1', ngram_range=(1, 2), stop_words='english')
X_features = tfidf.fit_transform(X.consumer_complaint_narrative).toarray()

# %%
# Create the Target
y = X['product_id']

# %% [markdown]
# ### Modeling

# %%
# Do cross-validation with multiple algorithms to select which to use
algorithms = [
    RandomForestClassifier(n_estimators=200, max_depth=3, random_state=123),
    LinearSVC(),
    MultinomialNB(),
    LogisticRegression(random_state=123),
]
CV = 5
cv_df = pd.DataFrame(index=range(CV * len(algorithms)))
entries = []
for algorithm in algorithms:
  algorithm_name = algorithm.__class__.__name__
  accuracies = cross_val_score(algorithm, X_features, y, scoring='accuracy', cv=CV)
  for fold_idx, accuracy in enumerate(accuracies):
    entries.append((algorithm_name, fold_idx, accuracy))
cv_df = pd.DataFrame(entries, columns=['algorithm_name', 'fold_idx', 'accuracy'])
cv_df
# Out:
#             algorithm_name  fold_idx  accuracy
# 0   RandomForestClassifier         0  0.409639
# 1   RandomForestClassifier         1  0.391566
# 2   RandomForestClassifier         2  0.439759
# 3   RandomForestClassifier         3  0.406061
# 4   RandomForestClassifier         4  0.412121
# 5                LinearSVC         0  0.771084
# 6                LinearSVC         1  0.813253
# 7                LinearSVC         2  0.813253
# 8                LinearSVC         3  0.781818
# 9                LinearSVC         4  0.745455
# 10           MultinomialNB         0  0.632530
# 11           MultinomialNB         1  0.638554
# 12           MultinomialNB         2  0.614458
# 13           MultinomialNB         3  0.600000
# 14           MultinomialNB         4  0.557576
# 15      LogisticRegression         0  0.722892
# 16      LogisticRegression         1  0.771084
# 17      LogisticRegression         2  0.746988
# 18      LogisticRegression         3  0.703030
# 19      LogisticRegression         4  0.715152

# %% [markdown]
# <font color='blue'>C1: Experiment with other classification algorithms, such as Nearest Neighbors</font><br>

# %%
# Plot Cross-Validation results
fig = plt.figure(figsize=(6,4))
cv_df.groupby('algorithm_name').accuracy.mean().plot.bar(ylim=0)
plt.show()

# %%
# Split into train and test
X_train, X_test, y_train, y_test = train_test_split(X_features, y, test_size=0.25, stratify=y, random_state=123)

# %%
# Train with the best algorithm - Linear SVC
classModel = LinearSVC()
classModel.fit(X_train, y_train)
# Out:
# LinearSVC()

# %% [markdown]
# ### Evaluation

# %%
# predict y for X_train and X_test
y_pred_train = classModel.predict(X_train) 
y_pred_test = classModel.predict(X_test)

# %%
# Plot consusion matrix of the test set results
product_id_df = X[['product', 'product_id']].drop_duplicates().sort_values('product_id')
conf_mat = confusion_matrix(y_test, y_pred_test)
fig, ax = plt.subplots(figsize=(8,6))
ax = sns.heatmap(conf_mat, annot=True, fmt='d',
    xticklabels=product_id_df['product'].values, yticklabels=product_id_df['product'].values)
bottom, top = ax.get_ylim() # These two lines were added due to bug on current Seaborn version
ax.set_ylim(bottom + 0.5, top - 0.5) #
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.show()

# %%
# Show metrics results
print(metrics.classification_report(y_test, y_pred_test, target_names=X['product'].unique()))
# Out:
#                          precision    recall  f1-score   support
#
#                Mortgage       0.93      0.90      0.91        29
# Bank account or service       0.69      0.73      0.71        15
#            Student loan       0.96      0.87      0.91        30
#        Credit reporting       0.77      0.77      0.77        31
#             Credit card       0.62      0.68      0.65        22
#         Debt collection       0.70      0.89      0.78        57
#           Consumer Loan       0.62      0.33      0.43        15
# Other financial service       0.00      0.00      0.00         1
#         Money transfers       0.00      0.00      0.00         3
#            Prepaid card       0.00      0.00      0.00         1
#             Payday loan       0.00      0.00      0.00         3
#
#                accuracy                           0.76       207
#               macro avg       0.48      0.47      0.47       207
#            weighted avg       0.74      0.76      0.74       207
#
# /Users/lagonick/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/lagonick/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /Users/lagonick/opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1248: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# <font color='blue'>C2: Experiment with a higher sample and hyper tunning the algorithm parameters</font><br>
